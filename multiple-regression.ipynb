# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Load dataset
dataset = pd.read_csv('Companies+spends+and+profits.csv')

# Display first few rows
print(dataset.head())

# Extract features (X) - Selecting valid column indices (IT, Staff_Training, Advertising)
X = dataset.iloc[:, [1, 2, 3]].values

# Extract target (y) - Profit (Column index 4)
y = dataset.iloc[:, 4].values

# One-Hot Encode categorical data (City column: index 0)
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [0])], remainder='passthrough')
X = ct.fit_transform(dataset.iloc[:, :-1])  # Apply transformation on all features except the target

# Split dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Define and train the regression model
reg = LinearRegression()
reg.fit(X_train, y_train)

# Predict the target values
y_pred = reg.predict(X_test)

# Display predictions alongside actual values
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred), 1), y_test.reshape(len(y_test), 1)), 1))

# Check model accuracy (R² score)
r2 = r2_score(y_test, y_pred)
print(f"R² Score: {r2:.4f}")
# Out:
#     City         IT  Staff_Training  Advertising     Profit
# 0  Paris  165349.20       236897.80    472784.20  182262.83
# 1   Rome  262597.70       182377.59    443898.53  172792.06
# 2   Rome  153442.52       172245.55    407934.54  162050.39
# 3  Paris  244372.42       138672.85    383299.62  282902.99
# 4   Rome  132207.34        92392.77    366268.42  266287.94
# [[161744.57 205008.32]
#  [152122.99 203282.38]
#  [175953.32 191050.39]
#  [149343.5  208733.99]
#  [139465.29  97483.56]
#  [155808.28 156991.12]
#  [231309.34 255752.6 ]
#  [128802.46 134307.35]
#  [133096.3   96479.52]
#  [114303.03 107404.34]
#  [131675.07 156121.95]
#  [143160.94 202004.64]
#  [130384.73  97427.84]
#  [116466.33  69758.98]
#  [128065.17  96722.8 ]]
# R² Score: 0.5445

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Load dataset
dataset = pd.read_csv('Companies+spends+and+profits.csv')

# Display first few rows
print(dataset.head())
# Out:
#     City         IT  Staff_Training  Advertising     Profit
# 0  Paris  165349.20       236897.80    472784.20  182262.83
# 1   Rome  262597.70       182377.59    443898.53  172792.06
# 2   Rome  153442.52       172245.55    407934.54  162050.39
# 3  Paris  244372.42       138672.85    383299.62  282902.99
# 4   Rome  132207.34        92392.77    366268.42  266287.94

# %%
# Extract features (X) - Selecting valid column indices (IT, Staff_Training, Advertising)
X = dataset.iloc[:, [1, 2, 3]].values

# Extract target (y) - Profit (Column index 4)
y = dataset.iloc[:, 4].values

# %%
# One-Hot Encode categorical data (City column: index 0)
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [0])], remainder='passthrough')
X = ct.fit_transform(dataset.iloc[:, :-1])  # Apply transformation on all features except the target

# %%
# Split dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Define and train the regression model
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict the target values
y_pred = reg.predict(X_test)

# %%
# Display predictions alongside actual values
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred), 1), y_test.reshape(len(y_test), 1)), 1))
# Out:
# [[161744.57 205008.32]
#  [152122.99 203282.38]
#  [175953.32 191050.39]
#  [149343.5  208733.99]
#  [139465.29  97483.56]
#  [155808.28 156991.12]
#  [231309.34 255752.6 ]
#  [128802.46 134307.35]
#  [133096.3   96479.52]
#  [114303.03 107404.34]
#  [131675.07 156121.95]
#  [143160.94 202004.64]
#  [130384.73  97427.84]
#  [116466.33  69758.98]
#  [128065.17  96722.8 ]]

# %%
# Check model accuracy (R² score)
r2 = r2_score(y_test, y_pred)
print(f"R² Score: {r2:.4f}")
# Out:
# R² Score: 0.5445

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

# Sample dataset (assuming it's structured similarly to your data)
data = dataset

# Convert to DataFrame
df = pd.DataFrame(data)

# Define independent (X) and dependent (y) variables
X = df[["IT", "Staff_Training", "Advertising"]]  # Independent variables
y = df["Profit"]  # Dependent variable

# Add constant term for OLS regression
X = sm.add_constant(X)

# Fit OLS model
model = sm.OLS(y, X).fit()

# Generate diagnostic plots
fig = plt.figure(figsize=(12, 8))
sm.graphics.plot_partregress_grid(model, fig=fig)

# Show plot
plt.show()

# Print summary statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.362
# Model:                            OLS   Adj. R-squared:                  0.333
# Method:                 Least Squares   F-statistic:                     12.67
# Date:                Wed, 19 Feb 2025   Prob (F-statistic):           1.18e-06
# Time:                        15:05:47   Log-Likelihood:                -864.79
# No. Observations:                  71   AIC:                             1738.
# Df Residuals:                      67   BIC:                             1747.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
print(ols_df)
# Out:
#          Variable   Coefficient    Std. Error t-Statistic   P-value  \
# 0           const  71160.000000  18200.000000       3.900  0.000000
# 1              IT      0.460400      0.117000       3.943  0.000000
# 2  Staff_Training      0.054400      0.046000       1.192  0.238000
# 3     Advertising      0.117200      0.066000       1.781  0.079000
#
#   95% Conf. Interval (Low) 95% Conf. Interval (High)
# 0             34700.000000             108000.000000
# 1                 0.227000                  0.694000
# 2                -0.037000                  0.146000
# 3                -0.014000                  0.249000

# %%
# Define the input values for IT, Staff Training, and Advertising
new_data = np.array([[1, 150000, 15, 10000]])  # Adding 1 for the constant term

# Predict profit using the trained OLS model
predicted_profit = model.predict(new_data)

# Display the predicted profit
predicted_profit
# Out:
# array([141398.47])
